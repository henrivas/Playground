# %%
x=5
x+7
# Out:
# 12

# %%
x=10
x/2
# Out:
# 5.0

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
name = "Henris"
surname = "Ivaskevicius"

# %%
print(surname)
# Out:
# Ivaskevicius

# %%
##slicing

# %%
## slicing

# %%
print(surname[3])
print(surname[0])
# Out:
# s
# I

# %% [markdown]
# # Skyrius

# %%
print(name)
# Out:
# Henris

# %%
print(surname)
# Out:
# Ivaskevicius

# %%
lygis = "penktas"

# %%
print(lygis)
# Out:
# penktas

# %%
len 'ilgis
'
# Out:
#   Cell In[13], line 1
#     len 'ilgis
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
len{'ilgis'}
# Out:
#   Cell In[14], line 1
#     len{'ilgis'}
#        ^
# SyntaxError: invalid syntax

# %%
len( 'ilgis' )
# Out:
# 5

# %%
lygis.upper()
# Out:
# 'PENKTAS'

# %%
print( lygis.upper(),
      name.lower()
        )
# Out:
# PENKTAS henris

# %%
tekstas = 'normalusis skirstinys yra'

# %%
tekstas.replace('yra', 'bus')
# Out:
# 'normalusis skirstinys bus'

# %%
print(name, surname)
# Out:
# Henris Ivaskevicius

# %%
uzduotis = 'Python makes me really really happy'

# %%
uzduotis.replace(uzduotis.find('Python'), 'PyThOn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/henriuzas/Desktop/Playground/Lesson1.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/Users/henriuzas/Desktop/Playground/Lesson1.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> uzduotis.replace(uzduotis.find('Python'), 'PyThOn')
#
# TypeError: replace() argument 1 must be str, not int

# %%
uzduotis.replace('Python', 'PyThOn')
# Out:
# 'PyThOn makes me really really happy'

# %%
string1 = 'Hello World, I am happy to learn Python!'

# %%
print(string1.[0:10])
# Out:
#   Cell In[25], line 1
#     print(string1.[0:10])
#                   ^
# SyntaxError: invalid syntax

# %%
print(string1[0:10])
# Out:
# Hello Worl

# %%
print(string1[14:18])
# Out:
#  am

# %%
print(string1[16:20])
# Out:
# m ha

# %%
len(string1)
# Out:
# 40

# %% [markdown]
# Skyrelis

# %%
print(f'I am {name} {surname} and I have {x} toes')
# Out:
# I am Henris Ivaskevicius and I have 10 toes

# %%
number1 = 59

# %%
number2 = 17

# %%
sum(number1, number2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/henriuzas/Desktop/Playground/Lesson1.ipynb Cell 35 line 1
# ----> <a href='vscode-notebook-cell:/Users/henriuzas/Desktop/Playground/Lesson1.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> sum(number1, number2)
#
# TypeError: 'int' object is not iterable

# %%
print(number1 + number2)
# Out:
# 76

# %%
number3 = 78.54

# %%
print(number2/number3)
# Out:
# 0.21645021645021642

# %%
print(f'18/5')
# Out:
# 18/5

# %%
print(150000000000/384000)
# Out:
# 390625.0

# %%
print(38400/150)
# Out:
# 256.0

# %%
print(f'59 - 17 = {number1 - number2}')
# Out:
# 59 - 17 = 42

# %%
print(f'Atstumas iki saules yra {150000000000/384000} kartu ilgesnis nei iki menulio')
# Out:
# Atstumas iki saules yra 390625.0 kartu ilgesnis nei iki menulio

# %%
from datetime import datetime, date, time
birthday = datetime(2000,12,25)
print(birthday)
now = datetime.now()
print (now)
time_passed = now - birthday
print (time_passed)
print (time_passed.days)
# Out:
# 2000-12-25 00:00:00
# 2023-09-28 21:08:17.916822
# 8312 days, 21:08:17.916822
# 8312

# %%
#boolean
bool1 = True
print(bool1)
print(type(bool1)
        )
bool2 = False
number = 1
print(bool(number))
# Out:
# True
# <class 'bool'>
# True

# %%
text = 'Hello world'
print ('w' in text)
# Out:
# True

# %%
print (5>3)
# Out:
# True
