# %%
pavadinimas = 'šuo' # Pirma uzduotis
amzius = '2 m.'
kailio_spalva = 'rudą'
svoris = '1.4 kg'

# %%
print(f'Gyvūnas - {pavadinimas} ({amzius}) turi {kailio_spalva} kailio spalvą ir sveria {svoris}.')
# Out:
# Gyvūnas - šuo (2 m.) turi rudą kailio spalvą ir sveria 1.4 kg.

# %%
zodis = 'desserts' # Antra uzduotis
apverstas = zodis[::-1]
print(apverstas)
# Out:
# stressed

# %%
needle = 'racecar' # Trecia uzduotis
haystack = 'The racecar is fast, but can it outrun a palindrome?'

# %%
print (needle in haystack)
# Out:
# True

# %%
bool_1 = True # Ketvirta uzduotis
number_string = '43'
number1 = int(number_string)
number2 = int(bool_1)
print( number1 + number2)
# Out:
# 44
